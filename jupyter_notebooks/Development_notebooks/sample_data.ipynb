# %%
import pandas as pd

# %%
metadata=pd.read_csv('../sample_input_files/meta_csv.txt')

# %%
metadata
# Out:
#                             filename  patient_id  tissue_id  subset_1  \
# 0   D233-LLN-CD8-TEM-rep4-200ng_S46         D233        LLN       CD8
# 1    D233-BM-CD8-TEM-rep4-200ng_S38         D233         BM       CD8
# 2     D299-BM-CD8-TRM-rep2-41ng_S72         D299         BM       CD8
# 3    D255-LLN-CD8-TRM-rep1-46ng_S47         D255        LLN       CD8
# 4    D280-LLN-CD8-TEM-rep2-26ng_S76         D280        LLN       CD8
# 5    D233-BM-CD8-TEM-rep3-200ng_S27         D233         BM       CD8
# 6     D255-BM-CD8-TRM-rep2-46ng_S57         D255         BM       CD8
# 7     D287-BM-CD8-TEM-rep4-55ng_S38         D287         BM       CD8
# 8     D255-BM-CD8-TEM-rep2-46ng_S58         D255         BM       CD8
# 9    D280-LLN-CD8-TEM-rep1-26ng_S86         D280        LLN       CD8
# 10   D287-LLN-CD8-TEM-rep2-55ng_S19         D287        LLN       CD8
# 11   D299-LLN-CD8-TEM-rep1-41ng_S90         D299        LLN       CD8
# ...

# %%
metadata.columns=metadata.columns.apply(lambda x: x.strip(' '))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-4592062684a3> in <module>()
# ----> 1 metadata.columns=metadata.columns.apply(lambda x: x.strip(' '))
#
# AttributeError: 'Index' object has no attribute 'apply'

# %%
metadata['filename'][0]
# Out:
# 'D233-LLN-CD8-TEM-rep4-200ng_S46'

# %%
metadata.to_csv('metadata.csv',index=False)

# %%
# Out:
# ' D233'
